# %% [markdown]
# ### Explicação do output:
#
#     Serão avaliados vários datasets, sendo inidicado qual está a ser avaliado no momento.
#
#     As métricas de avaliação do algoritmo base da SVM serão imprimidas primeiro.
#
#     Seguidamente, seguirão os valores da accuracy de cada SVM no ensemble
#
#     Finalmente, serão imprimidas as métricas de avaliação do ensemble sem o uso de pesos e com o uso de pesos.

# %%
from analyze import run
run()
# Out:
# Testing diabetes dataset.
# Accuracy of base SVM:  0.658008658008658
# Precision of base SVM:  0.5263157894736842
# Recall of base SVM:  0.7058823529411765
# f-Measure of base SVM:  0.6030150753768845
# Testing with diabetes dataset, 28 sub-datasets and 2 features
# SVM Accuracy:  0.38961038961038963
# SVM Accuracy:  0.43722943722943725
# SVM Accuracy:  0.645021645021645
# SVM Accuracy:  0.4588744588744589
# SVM Accuracy:  0.5627705627705628
# SVM Accuracy:  0.6363636363636364
# SVM Accuracy:  0.5800865800865801
# SVM Accuracy:  0.3722943722943723
# SVM Accuracy:  0.3722943722943723
# SVM Accuracy:  0.38961038961038963
# SVM Accuracy:  0.3722943722943723
# SVM Accuracy:  0.37662337662337664
# SVM Accuracy:  0.3722943722943723
# SVM Accuracy:  0.3939393939393939
# SVM Accuracy:  0.39826839826839827
# SVM Accuracy:  0.4155844155844156
# SVM Accuracy:  0.39826839826839827
# SVM Accuracy:  0.36796536796536794
# SVM Accuracy:  0.41125541125541126
# SVM Accuracy:  0.4805194805194805
# ...
